# %% [markdown]
# Try to change the noise parameter and see how the dynamics behaves.
#
# If $\eta=0$, then:

# %%
eta = 0

# Define the noisy best response dynamics

# Initialize transition rates matrix
n_config = n_actions**n_players
Lambda = sp.sparse.lil_matrix((n_config,n_config))

# Number of actions for each player
n_states =tuple(n_actions for _ in range(n_players))

# Fill transition rates matrix
for x_id in range(n_config):
    x = np.unravel_index(x_id,shape=n_states)
    x = np.array(x)
    for player in range(n_players):
        # compute utilities gained by `player` for each of its possible actions
        # while the other players are in the current configuration x
        utilities = np.zeros(n_actions)
        for action in actions:
            y = np.array(x)
            y[player] = action
            utilities[action] = utility(player,y,phi)
        # exp_utilities contains the exponential of utilities of 'player' for each possibile action
        exp_utilities = np.exp(eta*utilities)
        for action in actions:
            # there are no selfloops 
            if action == x[player]:
                continue
            y = np.array(x)
            y[player] = action
            y_id = np.ravel_multi_index(tuple(y), dims = n_states)
            # add a non-zero rate from x to y proportional to payoff of player when playing action (configuration is y)
            Lambda[x_id, y_id] += exp_utilities[action] / np.sum(exp_utilities)
            
            
# Simulate the continuous time Markov chain with 2nd approach: local clocks
w = np.sum(Lambda, axis=1)

# reshape w
w = np.array(w.T)[0]
for x, weight in enumerate(w):
    # add selfloop if a configuration is a sink, otherwise D is not well defined
    if weight == 0:
        Lambda[x,x] = 1
        w[x] = 1
D = np.diag(w)
P = np.linalg.inv(D) @ Lambda

# number of iterations
n_steps = 100

states = np.zeros(n_steps, dtype=int)
# initial configuration is random
x = np.random.choice(actions, size = n_players)
x_id = np.ravel_multi_index(tuple(x), dims = n_states)
states[0] = x_id

transition_times = np.zeros(n_steps)
t_next = -np.log(np.random.rand())/w[states[0]]

for i in range(1,n_steps):
    states[i] = np.random.choice(n_config, p=P[states[i-1],:])
    transition_times[i] = transition_times[i-1] + t_next
    t_next = -np.log(np.random.rand())/w[states[i]]
    
# Compute and plot the evolution of the potential along the simulated 
# path of the chain

# store the potential value at each step of the simulation
potentials = np.zeros(n_steps)
for step in range(n_steps):
    x_id = states[step]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    for i, j in G.edges:
        potentials[step] += pot[x[i],x[j]]
    potentials[step] /= 2

print("Potential along the simulated path of the chain:\n\n")
for t in range(n_steps):
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print("POTENTIAL:", potentials[t])
    print()

plt.step(transition_times, potentials, 'bo-', where="post");

intervals = np.diff(transition_times, n=1, append = transition_times[-1] + t_next)
avg_potential = np.sum(intervals*potentials)/(transition_times[-1] + t_next)
print("Average potential:", avg_potential)
print("Max potential:", np.max(potentials))
# Out:
# Potential along the simulated path of the chain:
#
#
# Jump step 0
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 1
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 2
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 3
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 6
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 7
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 8
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 9
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 11
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# POTENTIAL: 1.5
#
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.5
#
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 16
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 17
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 18
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 19
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 20
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 21
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 22
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 23
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 24
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 25
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 26
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 27
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 28
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 29
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.0
#
# Jump step 30
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.5
#
# Jump step 31
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.5
#
# Jump step 32
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 33
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 34
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 35
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 36
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 37
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 38
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 2.0
#
# Jump step 39
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 40
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 41
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 42
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 2.5
#
# Jump step 43
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 44
# state:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 45
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.0
#
# Jump step 46
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 47
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# POTENTIAL: 2.0
#
# Jump step 48
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 49
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# POTENTIAL: 2.0
#
# Jump step 50
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 51
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 52
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 53
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.0
#
# Jump step 54
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 55
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 56
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 57
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 58
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.5
#
# Jump step 59
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 60
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 61
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 62
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 2.0
#
# Jump step 63
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 64
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 65
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 66
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 67
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 68
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 69
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.0
#
# Jump step 70
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 71
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 72
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 2.5
#
# Jump step 73
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 74
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 2.0
#
# Jump step 75
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 76
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 77
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 78
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 79
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 80
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 81
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 82
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           0
# POTENTIAL: 1.0
#
# Jump step 83
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# POTENTIAL: 1.5
#
# Jump step 84
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.5
#
# Jump step 85
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 86
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 2.0
#
# Jump step 87
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 88
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 89
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.5
#
# Jump step 90
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 2.5
#
# Jump step 91
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 92
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 93
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.0
#
# Jump step 94
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           0
# POTENTIAL: 1.0
#
# Jump step 95
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 1.5
#
# Jump step 96
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 2.5
#
# Jump step 97
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 3.5
#
# Jump step 98
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# POTENTIAL: 2.5
#
# Jump step 99
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           0
# POTENTIAL: 2.0
#
# Average potential: 1.7718650959246973
# Max potential: 3.5

# %% [markdown]
# - the average potential is about 1.75, because transitions are random, the number of links is 7, and the potential counts the number of (undirected) links between nodes with same action. If the nodes choose randomly their state, in expectation the number of links between nodes with same action (and thus the potential is its half) is 3.5.

# %% [markdown]
# If $\eta=5$, then:

# %%
eta = 5

# Define the noisy best response dynamics

# Initialize transition rates matrix
n_config = n_actions**n_players
Lambda = sp.sparse.lil_matrix((n_config,n_config))

# Number of actions for each player
n_states =tuple(n_actions for _ in range(n_players))

# Fill transition rates matrix
for x_id in range(n_config):
    x = np.unravel_index(x_id,shape=n_states)
    x = np.array(x)
    for player in range(n_players):
        # compute utilities gained by `player` for each of its possible actions
        # while the other players are in the current configuration x
        utilities = np.zeros(n_actions)
        for action in actions:
            y = np.array(x)
            y[player] = action
            utilities[action] = utility(player,y,phi)
        # exp_utilities contains the exponential of utilities of 'player' for each possibile action
        exp_utilities = np.exp(eta*utilities)
        for action in actions:
            # there are no selfloops 
            if action == x[player]:
                continue
            y = np.array(x)
            y[player] = action
            y_id = np.ravel_multi_index(tuple(y), dims = n_states)
            # add a non-zero rate from x to y proportional to payoff of player when playing action (configuration is y)
            Lambda[x_id, y_id] += exp_utilities[action] / np.sum(exp_utilities)
            
            
# Simulate the continuous time Markov chain with 2nd approach: local clocks
w = np.sum(Lambda, axis=1)

# reshape w
w = np.array(w.T)[0]
for x, weight in enumerate(w):
    # add selfloop if a configuration is a sink, otherwise D is not well defined
    if weight == 0:
        Lambda[x,x] = 1
        w[x] = 1
D = np.diag(w)
P = np.linalg.inv(D) @ Lambda

# number of iterations
n_steps = 100

states = np.zeros(n_steps, dtype=int)
# initial configuration is random
x = np.random.choice(actions, size = n_players)
x_id = np.ravel_multi_index(tuple(x), dims = n_states)
states[0] = x_id

transition_times = np.zeros(n_steps)
t_next = -np.log(np.random.rand())/w[states[0]]

for i in range(1,n_steps):
    states[i] = np.random.choice(n_config, p=P[states[i-1],:])
    transition_times[i] = transition_times[i-1] + t_next
    t_next = -np.log(np.random.rand())/w[states[i]]
    
# Compute and plot the evolution of the potential along the simulated 
# path of the chain

# store the potential value at each step of the simulation
potentials = np.zeros(n_steps)
for step in range(n_steps):
    x_id = states[step]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    for i, j in G.edges:
        potentials[step] += pot[x[i],x[j]]
    potentials[step] /= 2

print("Potential along the simulated path of the chain:\n\n")
for t in range(n_steps):
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print("POTENTIAL:", potentials[t])
    print()

plt.step(transition_times, potentials, 'bo-', where="post");

intervals = np.diff(transition_times, n=1, append = transition_times[-1] + t_next)
avg_potential = np.sum(intervals*potentials)/(transition_times[-1] + t_next)
print("Average potential:", avg_potential)
print("Max potential:", np.max(potentials))
# Out:
# Potential along the simulated path of the chain:
#
#
# Jump step 0
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# POTENTIAL: 1.0
#
# Jump step 1
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 2
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 3
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 6
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 7
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 8
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 9
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 11
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 16
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 17
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 18
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 19
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 20
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 21
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 22
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 23
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 24
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 25
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 26
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 27
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 28
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 29
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 30
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 31
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 32
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 33
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 34
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 35
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 36
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 37
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 38
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 39
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 40
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 41
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 42
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 43
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 44
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 45
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 46
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 47
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 48
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 49
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 50
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 51
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 52
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 53
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 54
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 55
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 56
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 57
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 58
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 59
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 60
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 61
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 62
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 63
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 64
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 65
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 66
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 67
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 68
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 69
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 70
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 71
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 72
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 73
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 74
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 75
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 76
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 77
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 78
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 79
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 80
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 81
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 82
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 83
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 84
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 85
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 86
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 87
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 88
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 89
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 90
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 91
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 92
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 93
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 94
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 95
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 96
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 97
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 98
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 99
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Average potential: 3.4998885978128618
# Max potential: 3.5

# %% [markdown]
# - the dynamics spends most of the time in consensus configuration, thus the potential tends to 3.5, all the links connect nodes with same action;
# - <span style="background-color: #00FFFF">the average time between transitions increases, because it is unlikely that an agent modifies her action from a Nash equilibrium to achieve a lower payoff. Notice that the transition times increase only when the transition descends the potential.</span>

# %% [markdown]
# #### Step 2
# > Simulate the dynamics when  instead $a=1$, $b=\frac{1}{2}$ and $c=d=0$. Run the simulation a few times and plot the potential function as a function of time. What do you observe?
#
# The same code as previously can be reused, by only changing the parameter $b$. The simulations and the evolution of the potential values along it behave very similarly, with the difference that, among the states in which all nodes choose the same action, state $(0,\ldots,0)$ is much more frequent than $(1,\ldots,1)$. Even if all nodes are initialized to choose action 1, with high probability after a while they will all choose action 0 instead. This happens since with the current choice of $a,b,c,d$ the global maximum of the potential $\Phi$ is realized by the all-zero configuration.
#
# **Remark**: <span style="background-color: #00FFFF">note however that, in contrast with the best response dynamics, the noisy best response dynamics still will escape from global maximizers of the potential ('all zeros' states in this example), because the transition graph is irreducible.</span>

# %%
# Define the network coordination game

# number of nodes in G = number of players in the game
n_players = len(G)
# utility values
a = 1
b = 1/2
c = 0
d = 0
# utility matrix for the 2x2 coordination game
phi = np.array([[a,d],
                [c,b]])
# the potential function of the 2x2 coordination game
pot = np.array([[a-c,0],
                [0,b-d]])
# inverse noise parameter
eta = 5
# available actions
actions = [0,1]
n_actions = len(actions)
# adjacency matrix
W = nx.convert_matrix.to_numpy_matrix(G)

def utility(player, x, phi):
    result = 0
    for other_player in G.neighbors(player):
         result += phi[x[player], x[other_player]]
    return result

# %%
# Define the noisy best response dynamics

# Initialize transition rates matrix
n_config = n_actions**n_players
Lambda = sp.sparse.lil_matrix((n_config,n_config))

# Number of actions for each player
n_states =tuple(n_actions for _ in range(n_players))

# Fill transition rates matrix
for x_id in range(n_config):
    x = np.unravel_index(x_id,shape=n_states)
    x = np.array(x)
    for player in range(n_players):
        # compute utilities gained by `player` for each of its possible actions
        # while the other players are in the current configuration x
        utilities = np.zeros(n_actions)
        for action in actions:
            y = np.array(x)
            y[player] = action
            utilities[action] = utility(player,y,phi)
        exp_utilities = np.exp(eta*utilities)
        for action in actions:
            if action == x[player]:
                continue
            y = np.array(x)
            y[player] = action
            y_id = np.ravel_multi_index(tuple(y), dims = n_states)
            Lambda[x_id, y_id] += exp_utilities[action] / np.sum(exp_utilities)

# %%
# Simulate the continuous time Markov chain with 2nd approach: local clocks

w = np.sum(Lambda, axis=1)
w = np.array(w.T)[0]
for x, weight in enumerate(w):
    if weight == 0:
        Lambda[x,x] = 1
        w[x] = 1
D = np.diag(w)
P = np.linalg.inv(D) @ Lambda

# number of iterations
n_steps = 100

states = np.zeros(n_steps, dtype=int)
# initial configuration
x = np.random.choice(actions, size = n_players)
x_id = np.ravel_multi_index(tuple(x), dims = n_states)
states[0] = x_id

transition_times = np.zeros(n_steps)
t_next = -np.log(np.random.rand())/w[states[0]]

for i in range(1,n_steps):
    states[i] = np.random.choice(n_config, p=P[states[i-1],:])
    transition_times[i] = transition_times[i-1] + t_next
    t_next = -np.log(np.random.rand())/w[states[i]]

# %%
# Compute and plot the evolution of the potential along the simulated 
# path of the chain

# store the potential value at each step of the simulation
potentials = np.zeros(n_steps)
for step in range(n_steps):
    x_id = states[step]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    for i, j in G.edges:
        potentials[step] += pot[x[i],x[j]]
    potentials[step] /= 2

print("Potential along the simulated path of the chain:\n\n")
for t in range(n_steps):
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print("POTENTIAL:", potentials[t])
    print()

plt.step(transition_times, potentials, 'bo-', where="post");
# Out:
# Potential along the simulated path of the chain:
#
#
# Jump step 0
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 1
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# POTENTIAL: 1.0
#
# Jump step 2
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 3
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 6
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 7
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 8
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 9
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 11
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 16
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 17
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 18
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 19
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 20
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 21
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 22
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 23
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 24
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 25
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 26
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 27
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 28
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 29
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 30
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 31
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 32
# state:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.0
#
# Jump step 33
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 34
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 35
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 36
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 37
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 38
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 39
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 40
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 41
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 42
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 43
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 44
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 45
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 46
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 47
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 48
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 49
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 50
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 51
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 52
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 53
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 54
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 55
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 56
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 57
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 58
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 59
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 60
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 61
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 62
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 63
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 64
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 65
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 66
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 67
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 68
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 69
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 70
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 71
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 72
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# POTENTIAL: 2.0
#
# Jump step 73
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 74
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 75
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 76
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 77
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 78
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 79
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 80
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 81
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 82
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 83
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 84
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 85
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 86
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 87
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 88
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 89
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 90
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 91
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 92
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 93
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 94
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 95
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 96
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 97
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 98
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 99
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5

# %%
# To better understand the process, visualize the 
# evolution of the game's configuration in time

import matplotlib.pyplot as plt

# Plot the evolution of the game's configurations
fig = plt.figure(figsize=(9,12))
for t in range(0,min(n_steps,25)):
    plt.subplot(5,5,t+1)
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print()
    nx.draw(G,
        pos = pos,
        with_labels=True,
        nodelist=np.argwhere(x==0).T[0].tolist(),
        node_color = 'r')
    nx.draw(G,
        pos = pos,
        with_labels=True,
        nodelist=np.argwhere(x==1).T[0].tolist(),
        node_color = 'b')
    plt.title('jump step = {0}'.format(t+1))
# Out:
# Jump step 0
# state:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# Jump step 1
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# Jump step 2
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 3
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 6
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 7
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 8
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 9
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 11
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 16
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 17
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 18
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 19
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 20
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 21
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 22
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 23
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 24
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# **A few observations**
#
# - <span style="background-color: #00FFFF">Even if the noisy best response dynamics falls in the global maximum configuration (all zeros), still it will escape from this configuration, for any value of $\eta$, because the dynamics is ergodic.<span style="background-color: #00FFFF"> This is a crucial observation, which distinguishes the noisy best response from the best response.
#
# - <span style="background-color: #00FFFF">Also the 'all ones' configuration is a Nash equilibrium, and thus a local maximum of the potential. If $\eta$ is large and the system falls in the local maximum, it takes a lot to escape this configuration. This is due to the fact that the dynamics becomes "less ergodic" as $\eta$ grows large, in the sense that it takes a lot to escape from Nash equilibria, and in general it takes a lot to descend the potential, because the players become more rational as $\eta$ grows.</span>
#
# - <span style="background-color: #00FFFF">In mathematical terms, this statement may be rephrased as follows: "as $\eta$ grows large, the invariant distribution of the dynamics tends to concentrate most of the mass on the maximizers of the potential, but it takes more time to relax to the invariant distribution." This is also related to the fact that the transition graphs becomes less connected as $\eta$ grows (because the probability of an agent choosing a suboptimal strategy tends to $0$).</span>
#
# <span style="background-color: #00FFFF">(See **Remark: Ergodic Theorem** for details about ergodic dynamics).</span>

# %% [markdown]
# It is instructive to simulate the dynamics from the Nash equilibrium 'all ones' with a large value of $\eta$.

# %%
# Define the network coordination game

# number of nodes in G = number of players in the game
n_players = len(G)
# utility values
a = 1
b = 1/2
c = 0
d = 0
# utility matrix for the 2x2 coordination game
phi = np.array([[a,d],
                [c,b]])
# the potential function of the 2x2 coordination game
pot = np.array([[a-c,0],
                [0,b-d]])
# inverse noise parameter
eta = 10
# available actions
actions = [0,1]
n_actions = len(actions)
# adjacency matrix
W = nx.convert_matrix.to_numpy_matrix(G)

def utility(player, x, phi):
    result = 0
    for other_player in G.neighbors(player):
         result += phi[x[player], x[other_player]]
    return result

# %%
# Define the noisy best response dynamics

# Initialize transition rates matrix
n_config = n_actions**n_players
Lambda = sp.sparse.lil_matrix((n_config,n_config))

# Number of actions for each player
n_states =tuple(n_actions for _ in range(n_players))

# Fill transition rates matrix
for x_id in range(n_config):
    x = np.unravel_index(x_id,shape=n_states)
    x = np.array(x)
    for player in range(n_players):
        # compute utilities gained by `player` for each of its possible actions
        # while the other players are in the current configuration x
        utilities = np.zeros(n_actions)
        for action in actions:
            y = np.array(x)
            y[player] = action
            utilities[action] = utility(player,y,phi)
        exp_utilities = np.exp(eta*utilities)
        for action in actions:
            if action == x[player]:
                continue
            y = np.array(x)
            y[player] = action
            y_id = np.ravel_multi_index(tuple(y), dims = n_states)
            Lambda[x_id, y_id] += exp_utilities[action] / np.sum(exp_utilities)

# %%
# Simulate the continuous time Markov chain with 2nd approach: local clocks

w = np.sum(Lambda, axis=1)
w = np.array(w.T)[0]
for x, weight in enumerate(w):
    if weight == 0:
        Lambda[x,x] = 1
        w[x] = 1
D = np.diag(w)
P = np.linalg.inv(D) @ Lambda

# number of iterations
n_steps = 25

# initial configuration all ones
x_id = n_config-1
states[0] = x_id

transition_times = np.zeros(n_steps)
t_next = -np.log(np.random.rand())/w[0]

P_cum = np.cumsum(P, axis=1)

for i in range(1,n_steps):
    states[i] = np.random.choice(n_config, p=P[states[i-1],:])
    transition_times[i] = transition_times[i-1] + t_next
    t_next = -np.log(np.random.rand())/w[states[i]]

# %%
# Compute and plot the evolution of the potential along the simulated 
# path of the chain

# store the potential value at each step of the simulation
potentials = np.zeros(n_steps)
for step in range(n_steps):
    x_id = states[step]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    for i, j in G.edges:
        potentials[step] += pot[x[i],x[j]]
    potentials[step] /= 2

print("Potential along the simulated path of the chain:\n\n")
for t in range(n_steps):
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print("POTENTIAL:", potentials[t])
    print()

plt.step(transition_times, potentials, 'bo-', where="post");
# Out:
# Potential along the simulated path of the chain:
#
#
# Jump step 0
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 1.75
#
# Jump step 1
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 1.25
#
# Jump step 2
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 1.75
#
# Jump step 3
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# POTENTIAL: 1.25
#
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# POTENTIAL: 1.25
#
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# POTENTIAL: 1.75
#
# Jump step 6
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 7
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 8
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 9
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 11
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 16
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 17
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 18
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 19
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 20
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 2.5
#
# Jump step 21
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 22
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5
#
# Jump step 23
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# POTENTIAL: 3.5
#
# Jump step 24
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# POTENTIAL: 2.5

# %%
# To better understand the process, visualize the 
# evolution of the game's configuration in time

import matplotlib.pyplot as plt

# Plot the evolution of the game's configurations
fig = plt.figure(figsize=(18,24))
for t in range(0,min(n_steps,25)):
    plt.subplot(5,5,t+1)
    x_id = states[t]
    x = np.array(np.unravel_index(x_id, shape = n_states))
    print("Jump step " + str(t))
    print("state:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print()
    nx.draw(G,
        pos = pos,
        with_labels=True,
        nodelist=np.argwhere(x==0).T[0].tolist(),
        node_color = 'r')
    nx.draw(G,
        pos = pos,
        with_labels=True,
        nodelist=np.argwhere(x==1).T[0].tolist(),
        node_color = 'b')
    plt.title('trans time = {0}'.format(round(transition_times[t],3)))
# Out:
# Jump step 0
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# Jump step 1
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# Jump step 2
# state:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# Jump step 3
# state:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# Jump step 4
# state:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# Jump step 5
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# Jump step 6
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 7
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 8
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 9
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 10
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 11
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 12
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 13
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 14
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 15
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 16
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 17
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 18
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 19
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 20
# state:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 21
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 22
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# Jump step 23
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# Jump step 24
# state:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# <span style="background-color: #00FFFF">Observe that for a very long time interval the dynamics does not escape from the 'all ones' Nash equilibrium. However, as the simulation is observed for even longer times, the time spent in the 'all ones' configuration is expected to be a negligible fraction of the total time (as shown in the next step). This shows that for large $\eta$ it takes a lot to escape from local maxima and to relax to the invariant distribution $\pi$. If one considers instead the BR dynamics, the 'all ones' configuration belongs to $\mathcal{N}_\infty$ and the dynamics does not escape from that configuration.</span>

# %% [markdown]
# #### Step 3
# > If the simulation continues for a long time, will the probability to be in the different configurations converge towards some specific values? In that case, how can these be computed?
#
# <span style="background-color: #00FFFF">According to the theory about noisy best response dynamics, this type of dynamics is, for any choice of $\eta > 0$, an irreducible reversible Markov chain with invariant probability distribution</span>
# $$
# \pi_x = \frac{e^{\eta \Phi(x)}}{Z_\eta}, \quad Z_\eta = \sum_{y\in \mathcal{X}} e^{\eta \Phi(y)}.
# \tag{1}
# $$
#
# <span style="background-color: #00FFFF">(See **Remark: Irreversible Markov chain** for details about irreversible Markov chains).</span>
#
#
# Compute the values of $\pi$.

# %%
potentials = np.zeros(n_config)
for x_id in range(n_config):
    x = np.array(np.unravel_index(x_id, shape = n_states))
    for i, j in G.edges:
        potentials[x_id] += pot[x[i],x[j]]
    potentials[x_id] /= 2
exp_potentials = np.exp(eta*potentials)
pi = exp_potentials/np.sum(exp_potentials)

printmd("Invariant probability distribution " + "$\pi$:")
for x_id in range(n_config):
    x = np.array(np.unravel_index(x_id, shape = n_states))
    printmd("$\pi_x$ = " + str(pi[x_id]))
    printmd("with $x$:")
    df = pd.DataFrame(data=x, index=np.arange(len(G)), columns=['state'])
    df.index.name = 'player'
    display(df)
    print()
# Out:
# Invariant probability distribution $\pi$:
# $\pi_x$ = 0.9999085159650751
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# $\pi_x$ = 4.539577639372488e-05
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# $\pi_x$ = 3.058743353232534e-07
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# $\pi_x$ = 2.5107694394095215e-08
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# $\pi_x$ = 2.0609650597885773e-09
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# $\pi_x$ = 3.058743353232534e-07
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           0
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           0
# $\pi_x$ = 9.35676689573368e-14
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           0
# 4           1
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# $\pi_x$ = 4.539577639372488e-05
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# $\pi_x$ = 2.0609650597885773e-09
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           0
# 3           1
# 4           1
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
# $\pi_x$ = 9.35676689573368e-14
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# $\pi_x$ = 2.5107694394095215e-08
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# $\pi_x$ = 1.1398875619898573e-12
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           0
# $\pi_x$ = 1.3886673339822445e-11
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           0
# 4           1
# $\pi_x$ = 1.6917431409664886e-10
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# $\pi_x$ = 2.5107694394095215e-08
# with $x$:
#         state
# player
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# #### Step 4
# > Compute the ratio between the probability that after a long time (i.e., in stationarity) all nodes choose action 1 and the probability that all nodes choose action 0, both for case **1** and case **2**. Does this seem to agree with your simulations?
#
# According to (1), we have that
# $$
# \frac{\pi_{(1,1,1,1,1)}}{\pi_{(0,0,0,0,0)}} = \frac{e^{\eta \Phi(1,1,1,1,1)}}{e^{\eta \Phi(0,0,0,0,0)}}.
# $$
# We can thus compute the result according to the following code:

# %%
print("Case 1:")
# utility values
a = 1
b = 1
c = 0
d = 0
# the potential function of the 2x2 game
eta = 2
pot = np.array([[a-c,0],
                [0,b-d]])
x_0 = [0 for node in G]
potential_0 = 0
for i, j in G.edges:
    potential_0 += 0.5*pot[x_0[i],x_0[j]]

x_1 = [1 for node in G]
potential_1 = 0
for i, j in G.edges:
    potential_1 += 0.5*pot[x_1[i],x_1[j]]

probability_ratio_1_over_0 = np.exp(eta*potential_1) / np.exp(eta*potential_0)
print("The ratio between the probability of configuration 'all ones' and configuration 'all zeros' is", probability_ratio_1_over_0, "\n")

print("Case 2:")

# utility values
a = 1
b = 1/2
c = 0
d = 0
# the potential function of the 2x2 game
pot = np.array([[a-c,0],
                [0,b-d]])

x_0 = [0 for node in G]
potential_0 = 0
for i, j in G.edges:
    potential_0 += pot[x_0[i],x_0[j]]

x_1 = [1 for node in G]
potential_1 = 0
for i, j in G.edges:
    potential_1 += pot[x_1[i],x_1[j]]

probability_ratio_1_over_0 = np.exp(eta*potential_1) / np.exp(eta*potential_0)
print("The ratio between the probability of configuration 'all ones' and configuration 'all zeros' is", probability_ratio_1_over_0)
# Out:
# Case 1:
# The ratio between the probability of configuration 'all ones' and configuration 'all zeros' is 1.0
#
# Case 2:
# The ratio between the probability of configuration 'all ones' and configuration 'all zeros' is 0.0009118819655545161

# %% [markdown]
# Check if this result agrees with your simulations by estimating $\pi$ for case **1** and **2** by measuring the time spent in each configuration. Let's do a long simulation.

# %%
# number of nodes in G = number of players in the game
n_players = len(G)
# utility values
a = 1
b = 1/2
c = 0
d = 0
# utility matrix for the 2x2 coordination game
phi = np.array([[a,d],
                [c,b]])
# the potential function of the 2x2 coordination game
pot = np.array([[a-c,0],
                [0,b-d]])
# inverse noise parameter
eta = 2
# available actions
actions = [0,1]
n_actions = len(actions)
# adjacency matrix
W = nx.convert_matrix.to_numpy_matrix(G)

def utility(player, x, phi):
    result = 0
    for other_player in G.neighbors(player):
         result += phi[x[player], x[other_player]]
    return result

# %%
# Define the noisy best response dynamics

# Initialize transition rates matrix
n_config = n_actions**n_players
Lambda = sp.sparse.lil_matrix((n_config,n_config))

# Number of actions for each player
n_states =tuple(n_actions for _ in range(n_players))

# Fill transition rates matrix
for x_id in range(n_config):
    x = np.unravel_index(x_id,shape=n_states)
    x = np.array(x)
    for player in range(n_players):
        # compute utilities gained by `player` for each of its possible actions
        # while the other players are in the current configuration x
        utilities = np.zeros(n_actions)
        for action in actions:
            y = np.array(x)
            y[player] = action
            utilities[action] = utility(player,y,phi)
        exp_utilities = np.exp(eta*utilities)
        for action in actions:
            if action == x[player]:
                continue
            y = np.array(x)
            y[player] = action
            y_id = np.ravel_multi_index(tuple(y), dims = n_states)
            Lambda[x_id, y_id] += exp_utilities[action] / np.sum(exp_utilities)

# %%
#Simulate the continuous time Markov chain with 2nd approach: local clocks

w = np.sum(Lambda, axis=1)
w = np.array(w.T)[0]
for x, weight in enumerate(w):
    if weight == 0:
        Lambda[x,x] = 1
        w[x] = 1
D = np.diag(w)
P = np.linalg.inv(D) @ Lambda

# number of iterations
n_steps = 100000

states = np.zeros(n_steps, dtype=int)
# initial configuration
x = np.random.choice(actions, size = n_players)
x_id = np.ravel_multi_index(tuple(x), dims = n_states)
states[0] = x_id

transition_times = np.zeros(n_steps)
t_next = -np.log(np.random.rand())/w[0]

P_cum = np.cumsum(P, axis=1)

for i in range(1,n_steps):
    states[i] = np.random.choice(n_config, p=P[states[i-1],:])
    transition_times[i] = transition_times[i-1] + t_next
    t_next = -np.log(np.random.rand())/w[states[i]]

# %%
# compute frequencies
intervals = np.diff(transition_times, n=1, append = transition_times[-1] + t_next)
frequencies = np.zeros(n_config)

for node in range(n_config):
    visits = np.argwhere(states == node)
    frequencies[node] = np.sum(intervals[visits])/(transition_times[-1] + t_next)
print("Empirical frequencies:", frequencies, "\n")

print("Fraction of time spent in configuration", np.unravel_index(n_config-1, shape = n_states), "/ Fraction of time spent in configuration", np.unravel_index(0, shape = n_states), ":", frequencies[-1]/frequencies[0])
# Out:
# Empirical frequencies: [9.55817937e-01 1.71627192e-02 2.35040680e-03 8.49113755e-04
#  3.22525572e-04 1.29881496e-04 2.00128479e-05 1.20808488e-04
#  2.40605300e-03 3.77574323e-05 1.30219723e-04 4.59415213e-05
#  1.34203837e-05 4.95020917e-05 1.40901006e-05 1.38094450e-04
#  1.76236782e-02 3.17097378e-04 4.72799485e-05 1.91216786e-05
#  1.21809962e-04 3.86994370e-05 1.08829840e-05 4.04330889e-05
#  8.89981185e-04 1.85848804e-05 4.26385508e-05 1.62630143e-05
#  1.33609284e-04 4.07383140e-05 1.40537269e-04 8.90160596e-04]
#
# Fraction of time spent in configuration (1, 1, 1, 1, 1) / Fraction of time spent in configuration (0, 0, 0, 0, 0) : 0.0009313076902082402

# %% [markdown]
# #### Step 5.
# > Compute the ratio between the probability that after a long time (i.e., in stationarity) one node chooses action 1 and the rest choose action 0, and the probability that all nodes choose action 0, both for case **1** and case **2**.
#
# Using the invariant probability distribution formula (1) again, we can compute the ratio
#
# $$
# \frac{\sum_{i \in \mathcal V} \pi_{\delta(i)}}{\pi_{(0,0,0,0,0)}}
# $$
#
# where $\delta^{(i)}_i=1$ and $\delta^{(i)}_j=0$, $\forall j \neq i$.

# %%
print("Case 1:")
# utility values
a = 1
b = 1
c = 0
d = 0
# the potential function of the 2x2 game
pot = np.array([[a-c,0],
                [0,b-d]])
x_0 = [0 for node in G]
potential_0 = 0
for i, j in G.edges:
    potential_0 += 0.5*pot[x_0[i],x_0[j]]

exp_potential_1 = 0
for player in G:
    x_1 = [0 for node in G]
    x_1[player] = 1
    potential_1 = 0
    for i, j in G.edges:
        potential_1 += 0.5*pot[x_1[i],x_1[j]]
    exp_potential_1 += np.exp(eta*potential_1)

# print(exp_potential_1)
probability_ratio_1_over_0 = exp_potential_1 / np.exp(eta*potential_0)
print("The ratio between probability of configuration 'one player playing 1, rest playing 0' and configuration (0,0,0,0,0) is", probability_ratio_1_over_0, "\n")

print("Case 2:")

# utility values
a = 1
b = 1/2
c = 0
d = 0
# the potential function of the 2x2 game
pot = np.array([[a-c,0],
                [0,b-d]])

x_0 = [0 for node in G]
potential_0 = 0
for i, j in G.edges:
    potential_0 += 0.5*pot[x_0[i],x_0[j]]

exp_potential_1 = 0
for player in G:
    x_1 = [0 for node in G]
    x_1[player] = 1
    potential_1 = 0
    for i, j in G.edges:
        potential_1 += 0.5*pot[x_1[i],x_1[j]]
    exp_potential_1 += np.exp(eta*potential_1)

# print(exp_potential_1)
probability_ratio_1_over_0 = exp_potential_1 / np.exp(eta*potential_0)
print("The ratio between probability of configuration 'one player playing 1, rest playing 0' and configuration (0,0,0,0,0) is", probability_ratio_1_over_0)
# Out:
# Case 1:
# The ratio between probability of configuration 'one player playing 1, rest playing 0' and configuration (0,0,0,0,0) is 0.3885603420976875
#
# Case 2:
# The ratio between probability of configuration 'one player playing 1, rest playing 0' and configuration (0,0,0,0,0) is 0.3885603420976875

# %% [markdown]
# Even if in case 1 and 2 are different, the ratio
#
# $$
# \frac{\sum_{i \in \mathcal V} \pi_{\delta^{(i)}}}{\pi_{(0,0,0,0,0)}}
# $$
#
# is the same in the two cases.
# This happens because the potential value of configurations $\delta^(i)$ and $(0,0,0,0,0)$ does not depends on $b$, as the configurations does not contain any couple of neighboring players playing action $1$.

# %% [markdown]
# ## <span style="background-color: #00FFFF">On the difference between BR and NBR (in potential games)</span>
#
# - The NBR dynamics is irreducible, the BR is not (transitions are allowed only in the increasing direction of the potential).
# - The NBR dynamics admits a unique invariant distribution. The BR converges almost surely to the set of sink components of Nash equilibria (called recurrent equilibria, and indicated by $\mathcal{N}_\infty$). However, $\mathcal{N}_\infty$ may in general contain multiple disconnected sets of Nash equilibria, and which one is selected depends on the initial condition and on the realization of the Markov process.
# - As $\eta \to \infty$, the NBR dynamics for long times condensate its probability distribution to the global maximizers of the potential $\Phi$. However, $\mathcal{N}_\infty$ does not in general coincide with the global maximizers of the potential. The only property that can be proven is that $\mathcal{N}_\infty$ contains the global maxima of $\Phi$.

# %% [markdown]
# In the previous example, with $a=1, b=1/2$, both $x = \mathbf{1}$ and $x=\mathbf{0}$ are consensus states and Nash equilibria of the game. Both of them belong to $\mathcal{N}_\infty$. Indeed, if the configuration is $(1,1,1,1,1)$ or $(0,0,0,0,0)$ no rational agents modify their strategy, and the BR dynamics gets stucked in that configuration. However, $\Phi(1,1,1,1,1)<\Phi(0,0,0,0,0)$, thus the NBR dynamics with $\eta \to \infty$ for long times (after relaxating to the invariant distribution $\pi$) will spent almost fraction $1$ of the total time in $(0,0,0,0,0)$. Observe that this does not mean that the configuration $(0,0,0,0,0)$ is trapping for the NBR!!!

# %% [markdown]
# **Remark: Ergodic theorem**
#
#
# $\mathcal{G}$ strongly connected. For every $f : \mathcal{V} \rightarrow \mathcal{R}$, with probability 1,
#
# $$
# \lim_{t\to+\infty}\frac{1}{t+1} \sum_{s=0}^{t} f(X(s)) = \sum_{i \in \mathcal{V}} \pi_if(i)
# $$
#
# $X(t)$ Markov chain ergodic.
#
#
#
#
# Example:
# $$
# \lim_{t\to+\infty}\frac{n_{i_0}(t)}{t} = \pi_{i_0}
# $$
#
# with $n_{i_0}$: number of visits in $i_0$ before time $t$.

# %% [markdown]
# **Remark: Irreducible Markov chain**
#
# A Markov chain is irreducible if there is a non-zero probability of transitioning (even if in more than one step) from any state to any other state.
